# %%
import pandas as pd

# %%
data1 = pd.read_csv('data-1.csv')
data2 = pd.read_csv('data-2.csv')

# %%
data1.head()
# Out:
#              id  conversation_id    created_at       date      time  \
# 0  1.172170e+18     1.172170e+18  1.568300e+12  9/12/2019  22:09:46
# 1  1.172150e+18     1.172050e+18  1.568300e+12  9/12/2019  21:15:44
# 2  1.172140e+18     1.172140e+18  1.568290e+12  9/12/2019  20:25:44
# 3  1.172080e+18     1.172080e+18  1.568280e+12  9/12/2019  16:33:15
#
#                 timezone     user_id    username                name  place  \
# 0  SE Asia Standard Time  1701442309    nattazad            CHAtime™    NaN
# 1  SE Asia Standard Time  3074578447  beardpappa  Stephan February ⚡    NaN
# 2  SE Asia Standard Time    34601184      elmiza  علميزا قمرالزامن 👑    NaN
# 3  SE Asia Standard Time    22397966   williswee          Willis Wee    NaN
#
#    ...                                          quote_url video near  \
# 0  ...  https://twitter.com/4zlan_/status/117177927182...     0  NaN
# 1  ...                                                NaN     0  NaN
# ...

# %%
data2.head()
# Out:
#              id  conversation_id    created_at       date      time  \
# 0  1.172170e+18     1.172170e+18  1.568300e+12  9/12/2019  22:09:46
# 1  1.172150e+18     1.172050e+18  1.568300e+12  9/12/2019  21:15:44
# 2  1.172140e+18     1.172140e+18  1.568290e+12  9/12/2019  20:25:44
# 3  1.172080e+18     1.172080e+18  1.568280e+12  9/12/2019  16:33:15
#
#                 timezone     user_id    username                name  place  \
# 0  SE Asia Standard Time  1701442309    nattazad            CHAtime™    NaN
# 1  SE Asia Standard Time  3074578447  beardpappa  Stephan February ⚡    NaN
# 2  SE Asia Standard Time    34601184      elmiza  علميزا قمرالزامن 👑    NaN
# 3  SE Asia Standard Time    22397966   williswee          Willis Wee    NaN
#
#    ...                                          quote_url video near  \
# 0  ...  https://twitter.com/4zlan_/status/117177927182...     0  NaN
# 1  ...                                                NaN     0  NaN
# ...

# %%
frames = [data1, data2] 
result = pd.concat(frames).drop_duplicates().reset_index(drop=True)

# %%
result.head()
# Out:
#              id  conversation_id    created_at       date      time  \
# 0  1.172170e+18     1.172170e+18  1.568300e+12  9/12/2019  22:09:46
# 1  1.172150e+18     1.172050e+18  1.568300e+12  9/12/2019  21:15:44
# 2  1.172140e+18     1.172140e+18  1.568290e+12  9/12/2019  20:25:44
# 3  1.172080e+18     1.172080e+18  1.568280e+12  9/12/2019  16:33:15
#
#                 timezone     user_id    username                name  place  \
# 0  SE Asia Standard Time  1701442309    nattazad            CHAtime™    NaN
# 1  SE Asia Standard Time  3074578447  beardpappa  Stephan February ⚡    NaN
# 2  SE Asia Standard Time    34601184      elmiza  علميزا قمرالزامن 👑    NaN
# 3  SE Asia Standard Time    22397966   williswee          Willis Wee    NaN
#
#    ...                                          quote_url video near  \
# 0  ...  https://twitter.com/4zlan_/status/117177927182...     0  NaN
# 1  ...                                                NaN     0  NaN
# ...

# %%
result.to_csv(r'Mostretweeted.csv', index=False)
